# %%
import numpy as np
import geopandas as gpd
import rasterio
from pygeohydro import WBD

# %%
# lat, lon = 47.5, -121.8   # example WA Cascades

lat, lon = 48.310760, -120.657464

wbd = WBD("huc12")
huc12 = wbd.bygeom((lon, lat), geo_crs=4326)  # point query
huc12

# %%
huc12.plot()

# %%
list(huc12)

# %%
from pygeohydro import WBD

lat, lon = 48.310760, -120.657464

wbd8 = WBD("huc8")
huc8 = wbd8.bygeom((lon, lat), geo_crs=4326)
huc8

# %%
huc8.plot()

# %%
import folium

# If huc8 is a GeoDataFrame (it is), reproject to WGS84 for folium
huc8_wgs = huc12.to_crs(4326)

m = folium.Map(location=[lat, lon], zoom_start=8, tiles="CartoDB positron")

# add polygon
folium.GeoJson(
    huc8_wgs,
    name="HUC8",
    style_function=lambda x: {"weight": 2, "fillOpacity": 0.15},
).add_to(m)

# add query point
folium.Marker([lat, lon], tooltip="Query point").add_to(m)

folium.LayerControl().add_to(m)
m

# %%
# import geopandas as gpd
# from pygeohydro import WBD

# # 1) Get Washington state polygon (WGS84)
# wa = gpd.read_file("https://github.com/PublicaMundi/MappingAPI/raw/master/data/us-states.json")
# wa = wa[wa["name"] == "Washington"].to_crs(4326)

# # 2) Query WBD for all HUC12s intersecting WA
# wbd12 = WBD("huc12")
# wa_huc12 = wbd12.bygeom(wa.geometry.iloc[0], geo_crs=4326)

# wa_huc12

# %%
# import geopandas as gpd
# import pandas as pd
# from pygeohydro import WBD

# # 1) Washington polygon (WGS84)
# states_url = "https://www2.census.gov/geo/tiger/GENZ2023/shp/cb_2023_us_state_20m.zip"
# states = gpd.read_file(states_url).to_crs(4326)

# wa = states[states["STUSPS"] == "WA"].copy()
# wa_geom = wa.geometry.iloc[0]  # can be MultiPolygon

# # 2) Split WA into Polygon parts (because bygeom() may not accept MultiPolygon)
# if wa_geom.geom_type == "MultiPolygon":
#     wa_parts = list(wa_geom.geoms)
# else:
#     wa_parts = [wa_geom]

# # 3) Query HUC12 intersecting WA (union of all parts)
# wbd12 = WBD("huc12")
# pieces = []
# for poly in wa_parts:
#     pieces.append(wbd12.bygeom(poly, geo_crs=4326))

# huc12_wa = gpd.GeoDataFrame(pd.concat(pieces, ignore_index=True), crs=4326)

# # de-duplicate by HUC id (sometimes overlaps between parts)
# if "huc12" in huc12_wa.columns:
#     huc12_wa = huc12_wa.drop_duplicates(subset=["huc12"])

# # 4) Clip to WA boundary (final clean WA-only geometry)
# huc12_wa_clipped = gpd.clip(huc12_wa, wa.to_crs(4326))

# print("HUC12 rows (intersect WA):", len(huc12_wa))
# print("HUC12 rows (clipped):", len(huc12_wa_clipped))

# huc12_wa_clipped.head()

# %%
# --- Get HUC12 polygons within a bounding box (no WA clipping) ---

minx, miny, maxx, maxy = -123.6, 46.6, -119.9, 49.4
bbox = box(minx, miny, maxx, maxy)

# 2) Query WBD for HUC12 features intersecting the bbox
wbd12 = WBD("huc12")
huc12 = wbd12.bygeom(bbox, geo_crs=4326)  # returns a GeoDataFrame

print("HUC12 rows:", len(huc12))
huc12.head()

# 3) (Optional) hard-clip geometries to the bbox
bbox_gdf = gpd.GeoDataFrame(geometry=[bbox], crs=4326)
huc12_clip = gpd.clip(huc12.to_crs(4326), bbox_gdf)

print("Clipped rows:", len(huc12_clip))
huc12_clip.head()

# %%
from pathlib import Path

import geopandas as gpd
import rasterio
from rasterio.mask import mask
from bmi_topography import Topography


def fetch_clipped_dem_for_aoi(
    aoi_path: str,
    out_dir: str = r"/mnt/c/Users/amehedi/Downloads",
    dem_type: str = "SRTMGL1",
    output_format: str = "GTiff",
    buffer_deg: float = 0.0,
    api_key: str | None = None,
    cache_dir: str | None = None,
) -> str:
    out_dir = Path(out_dir)
    out_dir.mkdir(parents=True, exist_ok=True)

    cache_dir = Path(cache_dir) if cache_dir else out_dir / "dem_cache"
    cache_dir.mkdir(parents=True, exist_ok=True)

    gdf = gpd.read_file(aoi_path)
    gdf_wgs84 = gdf.to_crs(epsg=4326)
    west, south, east, north = gdf_wgs84.total_bounds

    topo = Topography(
        dem_type=dem_type,
        south=south - buffer_deg,
        north=north + buffer_deg,
        west=west - buffer_deg,
        east=east + buffer_deg,
        output_format=output_format,
        cache_dir=str(cache_dir),
        api_key=api_key,
    )
    dem_path = Path(topo.fetch())

    with rasterio.open(dem_path) as src:
        gdf_src = gdf.to_crs(src.crs)
        shapes = [geom.__geo_interface__ for geom in gdf_src.geometry]
        out_image, out_transform = mask(src, shapes, crop=True)

        out_meta = src.meta.copy()
        out_meta.update(
            {
                "driver": "GTiff",
                "height": out_image.shape[1],
                "width": out_image.shape[2],
                "transform": out_transform,
            }
        )

    out_path = out_dir / f"dem_{dem_type.lower()}_clipped.tif"
    with rasterio.open(out_path, "w", **out_meta) as dst:
        dst.write(out_image)

    return str(out_path)

# %%
dem_path = fetch_clipped_dem_for_aoi(
    r"/mnt/c/Users/amehedi/Downloads/purple_creek_da.gpkg"
)
print(dem_path)

# %%
from pathlib import Path

import geopandas as gpd
import numpy as np
import rasterio
from rasterio.mask import mask
from bmi_topography import Topography


def _write_esri_ascii(
    array_2d: np.ndarray,
    transform,
    out_path: Path,
    nodata_value: float,
) -> str:
    height, width = array_2d.shape
    xllcorner = transform.c
    yllcorner = transform.f + transform.e * height
    cellsize = abs(transform.a)

    with open(out_path, "w") as f:
        f.write(f"ncols         {width}\n")
        f.write(f"nrows         {height}\n")
        f.write(f"xllcorner     {xllcorner}\n")
        f.write(f"yllcorner     {yllcorner}\n")
        f.write(f"cellsize      {cellsize}\n")
        f.write(f"NODATA_value  {nodata_value}\n")
        for row in array_2d:
            f.write(" ".join(map(str, row)) + "\n")

    return str(out_path)


def _force_overwrite(path: Path) -> None:
    if path.exists():
        try:
            path.unlink()
        except Exception as e:
            raise PermissionError(
                f"Could not overwrite {path}. Close the file (QGIS/ArcGIS/preview) and retry."
            ) from e


def fetch_clipped_dem_for_aoi(
    aoi_path: str,
    out_dir: str = r"/mnt/c/Users/amehedi/Downloads",
    dem_type: str = "SRTMGL1",
    output_format: str = "GTiff",
    buffer_deg: float = 0.0,
    api_key: str | None = None,
    cache_dir: str | None = None,
    nodata_value: float = -9999.0,
) -> tuple[str, str]:
    out_dir = Path(out_dir)
    out_dir.mkdir(parents=True, exist_ok=True)

    cache_dir = Path(cache_dir) if cache_dir else out_dir / "dem_cache"
    cache_dir.mkdir(parents=True, exist_ok=True)

    gdf = gpd.read_file(aoi_path)
    gdf_wgs84 = gdf.to_crs(epsg=4326)
    west, south, east, north = gdf_wgs84.total_bounds

    topo = Topography(
        dem_type=dem_type,
        south=south - buffer_deg,
        north=north + buffer_deg,
        west=west - buffer_deg,
        east=east + buffer_deg,
        output_format=output_format,
        cache_dir=str(cache_dir),
        api_key=api_key,
    )
    dem_path = Path(topo.fetch())

    with rasterio.open(dem_path) as src:
        gdf_src = gdf.to_crs(src.crs)
        shapes = [geom.__geo_interface__ for geom in gdf_src.geometry]
        out_image, out_transform = mask(src, shapes, crop=True)

        nd = src.nodata if src.nodata is not None else nodata_value

        out_meta = src.meta.copy()
        out_meta.update(
            {
                "driver": "GTiff",
                "height": out_image.shape[1],
                "width": out_image.shape[2],
                "transform": out_transform,
                "nodata": nd,
            }
        )

    out_tif = out_dir / f"dem_{dem_type.lower()}_clipped.tif"
    out_asc = out_dir / f"dem_{dem_type.lower()}_clipped.asc"

    _force_overwrite(out_tif)
    _force_overwrite(out_asc)

    with rasterio.open(out_tif, "w", **out_meta) as dst:
        dst.write(out_image)

    arr = out_image[0].astype(float)
    arr[arr == nd] = np.nan
    arr_out = np.where(np.isnan(arr), nd, arr)

    _write_esri_ascii(arr_out, out_transform, out_asc, nd)

    return str(out_tif), str(out_asc)


# ---- example ----
tif_path, asc_path = fetch_clipped_dem_for_aoi(
    r"/mnt/c/Users/amehedi/Downloads/purple_creek_da.gpkg"
)
print(tif_path)
print(asc_path)

# %%
import numpy as np
import rasterio
import matplotlib.pyplot as plt

tif_path = r"/mnt/c/Users/amehedi/Downloads/dem_srtmgl1_clipped.tif"
asc_path = r"/mnt/c/Users/amehedi/Downloads/dem_srtmgl1_clipped.asc"

def quick_plot_tif(path):
    with rasterio.open(path) as src:
        z = src.read(1).astype(float)
        if src.nodata is not None:
            z[z == src.nodata] = np.nan
    print("TIF min/max:", np.nanmin(z), np.nanmax(z))
    plt.figure(figsize=(6,5))
    plt.imshow(z, cmap="terrain")
    plt.colorbar(label="Elevation")
    plt.title("Clipped DEM (TIF)")
    plt.axis("off")
    plt.show()

def quick_plot_asc(path):
    with open(path) as f:
        header = [next(f) for _ in range(6)]
    nodata = float([h for h in header if "NODATA" in h.upper()][0].split()[-1])
    z = np.loadtxt(path, skiprows=6)
    z[z == nodata] = np.nan
    print("ASC min/max:", np.nanmin(z), np.nanmax(z))
    plt.figure(figsize=(6,5))
    plt.imshow(z, cmap="terrain")
    plt.colorbar(label="Elevation")
    plt.title("Clipped DEM (ASC)")
    plt.axis("off")
    plt.show()

quick_plot_tif(tif_path)
quick_plot_asc(asc_path)

# %%
from pathlib import Path

import geopandas as gpd
import numpy as np
import rasterio
from rasterio.mask import mask
from rasterio.warp import calculate_default_transform, reproject, Resampling
from bmi_topography import Topography


def _write_esri_ascii(array_2d, transform, out_path, nodata_value):
    height, width = array_2d.shape
    xllcorner = transform.c
    yllcorner = transform.f + transform.e * height
    cellsize = abs(transform.a)

    with open(out_path, "w") as f:
        f.write(f"ncols         {width}\n")
        f.write(f"nrows         {height}\n")
        f.write(f"xllcorner     {xllcorner}\n")
        f.write(f"yllcorner     {yllcorner}\n")
        f.write(f"cellsize      {cellsize}\n")
        f.write(f"NODATA_value  {nodata_value}\n")
        for row in array_2d:
            f.write(" ".join(map(str, row)) + "\n")

    return str(out_path)


def _force_overwrite(path: Path):
    if path.exists():
        path.unlink()


def fetch_clipped_dem_for_aoi(
    aoi_path: str,
    out_dir: str,
    dem_type: str = "USGS10m",
    target_resolution: float = 10.0,
    buffer_deg: float = 0.05,
    api_key: str | None = None,
    nodata_value: float = -9999.0,
):
    out_dir = Path(out_dir)
    out_dir.mkdir(parents=True, exist_ok=True)

    # ---- AOI + UTM detection ----
    gdf = gpd.read_file(aoi_path)

    centroid = gdf.to_crs(4326).geometry.unary_union.centroid
    zone = int((centroid.x + 180) / 6) + 1
    epsg = 32600 + zone if centroid.y >= 0 else 32700 + zone
    gdf_utm = gdf.to_crs(epsg=epsg)

    # ---- Download DEM ----
    west, south, east, north = gdf.to_crs(4326).total_bounds

    topo = Topography(
        dem_type=dem_type,
        south=south - buffer_deg,
        north=north + buffer_deg,
        west=west - buffer_deg,
        east=east + buffer_deg,
        output_format="GTiff",
        api_key=api_key,
    )
    dem_path = Path(topo.fetch())

    # ---- Clip DEM ----
    with rasterio.open(dem_path) as src:
        shapes = [geom.__geo_interface__ for geom in gdf.to_crs(src.crs).geometry]
        clipped, clip_transform = mask(src, shapes, crop=True)
        src_crs = src.crs
        src_nodata = src.nodata if src.nodata is not None else nodata_value

    # ---- Reproject + resample to UTM ----
    dst_transform, width, height = calculate_default_transform(
        src_crs,
        f"EPSG:{epsg}",
        clipped.shape[2],
        clipped.shape[1],
        *rasterio.transform.array_bounds(
            clipped.shape[1], clipped.shape[2], clip_transform
        ),
        resolution=target_resolution,
    )

    dst = np.empty((1, height, width), dtype=np.float32)

    reproject(
        source=clipped,
        destination=dst,
        src_transform=clip_transform,
        src_crs=src_crs,
        dst_transform=dst_transform,
        dst_crs=f"EPSG:{epsg}",
        resampling=Resampling.bilinear,
        src_nodata=src_nodata,
        dst_nodata=src_nodata,
    )

    # ---- Write outputs ----
    out_tif = out_dir / f"dem_utm_{int(target_resolution)}m.tif"
    out_asc = out_dir / f"dem_utm_{int(target_resolution)}m.asc"

    _force_overwrite(out_tif)
    _force_overwrite(out_asc)

    with rasterio.open(
        out_tif,
        "w",
        driver="GTiff",
        height=height,
        width=width,
        count=1,
        dtype=dst.dtype,
        crs=f"EPSG:{epsg}",
        transform=dst_transform,
        nodata=src_nodata,
    ) as ds:
        ds.write(dst)

    arr = dst[0]
    arr[np.isnan(arr)] = src_nodata
    _write_esri_ascii(arr, dst_transform, out_asc, src_nodata)

    return str(out_tif), str(out_asc)

# %%
tif, asc = fetch_clipped_dem_for_aoi(
    aoi_path="/mnt/c/Users/amehedi/Downloads/purple_creek_da.gpkg",
    out_dir="/mnt/c/Users/amehedi/Downloads",
    api_key="985ca66e17da97a20d0732c993597ea3"
)

print(tif)
print(asc)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np


def inspect_dem(dem_path):
    """
    Print CRS, resolution, bounds, shape
    """
    with rasterio.open(dem_path) as src:
        print("CRS:", src.crs)
        print("EPSG:", src.crs.to_epsg())
        print("Resolution (x, y):", src.res)
        print("Width, Height:", src.width, src.height)
        print("Bounds:", src.bounds)
        print("NoData:", src.nodata)


def plot_dem(dem_path, cmap="terrain"):
    """
    Quick DEM map plot
    """
    with rasterio.open(dem_path) as src:
        dem = src.read(1)
        dem = np.ma.masked_equal(dem, src.nodata)

    plt.figure(figsize=(8, 6))
    plt.imshow(dem, cmap=cmap)
    plt.colorbar(label="Elevation (m)")
    plt.title("DEM")
    plt.axis("off")
    plt.tight_layout()
    plt.show()


# ---- usage ----
dem_path = "/mnt/c/Users/amehedi/Downloads/dem_utm_10m.tif"

inspect_dem(dem_path)
plot_dem(dem_path)

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np


def plot_dem_simple(dem_path):
    with rasterio.open(dem_path) as src:
        dem = src.read(1)
        dem = np.ma.masked_equal(dem, src.nodata)
        extent = [
            src.bounds.left,
            src.bounds.right,
            src.bounds.bottom,
            src.bounds.top,
        ]

    plt.figure(figsize=(6, 6))
    plt.imshow(dem, extent=extent, origin="upper", cmap="terrain")
    plt.colorbar(label="Elevation (m)")
    plt.xlabel("X (m)")
    plt.ylabel("Y (m)")
    plt.title("Elevation")
    plt.tight_layout()
    plt.show()


# ---- usage ----
plot_dem_simple("/mnt/c/Users/amehedi/Downloads/dem_utm_10m.tif")

# %%
import pandas as pd

csv_path = "/mnt/c/Users/amehedi/Downloads/Change_Detection_Data_Release.csv"
df = pd.read_csv(csv_path)
df.columns

subset = df[df["Data_Availability_Category"] == "pre_and_post"][["Fire_ID", "Fire_Name"]]
subset

# %%
from pathlib import Path
import sys

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import yaml

# Find repo root whether notebook runs from repo root or notebook/
REPO_ROOT = Path.cwd()
if not (REPO_ROOT / "src").exists():
    REPO_ROOT = REPO_ROOT.parent

SRC = REPO_ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

from ml.dataset import discover_feature_paths
from deep.data import load_feature_target_stack

CONFIG_PATH = REPO_ROOT / "config" / "ml_rf.yaml"   # change if needed
MAX_SAMPLES = 100_000                                  # set None to use all valid pixels
RANDOM_STATE = 42

# %%
with open(CONFIG_PATH, "r") as f:
    cfg = yaml.safe_load(f)

data_cfg = cfg["data"]
data_dir = Path(data_cfg["dir"])
target_name = data_cfg.get("target_name", "dem_diff.tif")
target_path = data_dir / target_name

feature_paths = discover_feature_paths(
    data_dir=data_dir,
    target_name=target_name,
    include_names=data_cfg.get("include_names"),
    include_glob=data_cfg.get("include_glob", "*.tif"),
    exclude_names=data_cfg.get("exclude_names"),
    exclude_contains=data_cfg.get("exclude_contains"),
)

bundle = load_feature_target_stack(feature_paths, target_path)

feature_names = bundle["feature_names"]
valid_mask = bundle["valid_mask"]
y_grid = bundle["y"]
x_grid = bundle["X"]

print("Data dir:", data_dir)
print("Target:", target_name)
print("Number of features:", len(feature_names))
print("Feature names:")
for name in feature_names:
    print(" -", name)
print("Raster shape:", y_grid.shape)
print("Valid fraction:", float(valid_mask.mean()))
# Out:
# Data dir: /mnt/c/Users/amehedi/Downloads/ml_debris/output/thomas
# Target: dem_diff.tif
# Number of features: 23
# Feature names:
#  - burn__severity
#  - cation__exchange_capacity
#  - clay__total
#  - dry__bulk_density
#  - field__capacity
#  - landcover
#  - pH
#  - porosity
#  - sand__total
#  - saturated__water_content
#  - silt__total
#  - soil__density
#  - soil__internal_friction_angle
#  - soil__maximum_total_cohesion
#  - soil__minimum_total_cohesion
#  - soil__mode_total_cohesion
#  - soil__saturated_hydraulic_conductivity
#  - soil__texture
#  - soil__thickness
#  - soil__transmissivity
#  - topographic__elevation
#  - vegetation__plant_functional_type
#  - wilting__point
# Raster shape: (835, 716)
# Valid fraction: 0.8842053323520557

# %%
# Flatten valid pixels into a table
X_valid = np.stack([x_grid[i][valid_mask] for i in range(x_grid.shape[0])], axis=1)
y_valid = y_grid[valid_mask]

df = pd.DataFrame(X_valid, columns=feature_names)
df["dem_diff"] = y_valid

if MAX_SAMPLES is not None and len(df) > MAX_SAMPLES:
    df = df.sample(MAX_SAMPLES, random_state=RANDOM_STATE)

display(df.head())
print("Samples used for EDA:", len(df))
# Out:
#         burn__severity  cation__exchange_capacity  clay__total  \
# 169272             0.0                      164.0         17.0
# 488477             0.0                      180.0         20.0
# 76799              0.0                      150.0         18.0
# 80018              0.0                      118.0         16.0
# 157355             0.0                      165.0         16.0
#
#         dry__bulk_density  field__capacity  landcover     pH  porosity  \
# 169272              163.0         0.249379       52.0  592.0     0.435
# 488477              164.0         0.314610       21.0  667.0     0.451
# 76799               163.0         0.249379       52.0  603.0     0.435
# 80018               163.0         0.249379       42.0  604.0     0.435
# 157355              163.0         0.249379       52.0  590.0     0.435
#
#         sand__total  saturated__water_content  ...  \
# 169272         62.0                  0.379427  ...
# 488477         52.0                  0.378733  ...
# 76799          61.0                  0.379700  ...
# 80018          61.0                  0.379342  ...
# 157355         64.0                  0.378968  ...
#
#         soil__minimum_total_cohesion  soil__mode_total_cohesion  \
# 169272                        2000.0                     4000.0
# 488477                          30.0                      100.0
# 76799                         2000.0                     4000.0
# 80018                         4000.0                    10000.0
# 157355                        2000.0                     4000.0
#
#         soil__saturated_hydraulic_conductivity  soil__texture  \
# 169272                                3.651408            3.0
# 488477                                3.831311            4.0
# 76799                                 3.823284            3.0
# 80018                                 4.489467            3.0
# 157355                                3.909651            3.0
#
#         soil__thickness  soil__transmissivity  topographic__elevation  \
# 169272             18.0              0.657254              722.941650
# 488477            114.0              4.367694               62.075813
# 76799              37.0              1.414615              810.169434
# 80018              27.0              1.212156             1012.232178
# 157355             27.0              1.055606              750.096313
#
#         vegetation__plant_functional_type  wilting__point  dem_diff
# 169272                                1.0        0.096446  0.026855
# 488477                                3.0        0.132649 -0.033291
# 76799                                 1.0        0.096446 -0.568909
# 80018                                 2.0        0.096446  0.200439
# 157355                                1.0        0.096446 -0.234253
#
# [5 rows x 24 columns]
# Samples used for EDA: 100000

# %%
summary = df.describe().T
summary["missing_frac"] = df.isna().mean()
summary = summary[["count", "mean", "std", "min", "25%", "50%", "75%", "max", "missing_frac"]]
display(summary.sort_index())
# Out:
#                                            count         mean          std  \
# burn__severity                          100000.0     0.000000     0.000000
# cation__exchange_capacity               100000.0   174.172073    28.016483
# clay__total                             100000.0    18.465099     2.025059
# dem_diff                                100000.0    -0.133375     0.639984
# dry__bulk_density                       100000.0   162.102036     1.730826
# field__capacity                         100000.0     0.265931     0.028206
# landcover                               100000.0    40.574360    15.340749
# pH                                      100000.0   633.477295    40.499153
# porosity                                100000.0     0.438695     0.007190
# sand__total                             100000.0    56.248371     5.059889
# saturated__water_content                100000.0     0.383163     0.005180
# silt__total                             100000.0    25.286840     3.456444
# soil__density                           100000.0  2888.445557    49.620613
# soil__internal_friction_angle           100000.0    31.296200     1.691507
# soil__maximum_total_cohesion            100000.0  7440.706055  6415.655762
# soil__minimum_total_cohesion            100000.0  1489.209473  1284.305298
# soil__mode_total_cohesion               100000.0  3223.890869  3038.720459
# soil__saturated_hydraulic_conductivity  100000.0     3.808874     0.827276
# soil__texture                           100000.0     3.297070     0.607966
# soil__thickness                         100000.0    73.688316    56.149307
# soil__transmissivity                    100000.0     3.034188     2.959914
# topographic__elevation                  100000.0   457.493347   349.777832
# vegetation__plant_functional_type       100000.0     1.820070     0.966884
# wilting__point                          100000.0     0.106054     0.016548
#
#                                                 min          25%  \
# burn__severity                             0.000000     0.000000
# cation__exchange_capacity                110.000000   154.000000
# clay__total                               14.000000    17.000000
# dem_diff                                 -13.812500    -0.220156
# dry__bulk_density                        153.000000   161.000000
# field__capacity                            0.249379     0.249379
# landcover                                 21.000000    22.000000
# pH                                       567.000000   598.000000
# porosity                                   0.420000     0.435000
# sand__total                               44.000000    52.000000
# saturated__water_content                   0.370401     0.379427
# silt__total                               17.000000    22.000000
# soil__density                           2707.964600  2867.256592
# soil__internal_friction_angle             27.000000    30.000000
# soil__maximum_total_cohesion             150.000000   150.000000
# soil__minimum_total_cohesion              30.000000    30.000000
# soil__mode_total_cohesion                100.000000   100.000000
# soil__saturated_hydraulic_conductivity     2.185691     3.246669
# soil__texture                              3.000000     3.000000
# soil__thickness                            1.000000    29.000000
# soil__transmissivity                       0.100000     1.015906
# topographic__elevation                     2.975780   137.027069
# vegetation__plant_functional_type          0.000000     1.000000
# wilting__point                             0.096446     0.096446
#
#                                                  50%           75%  \
# burn__severity                              0.000000      0.000000
# cation__exchange_capacity                 176.000000    195.000000
# clay__total                                18.000000     20.000000
# dem_diff                                   -0.082520     -0.002930
# dry__bulk_density                         162.000000    163.000000
# field__capacity                             0.249379      0.299385
# landcover                                  52.000000     52.000000
# pH                                        618.000000    676.000000
# porosity                                    0.435000      0.435000
# sand__total                                57.000000     61.000000
# saturated__water_content                    0.382436      0.386178
# silt__total                                26.000000     28.000000
# soil__density                            2884.955811   2902.654785
# soil__internal_friction_angle              30.000000     33.000000
# soil__maximum_total_cohesion            10000.000000  10000.000000
# soil__minimum_total_cohesion             2000.000000   2000.000000
# soil__mode_total_cohesion                4000.000000   4000.000000
# soil__saturated_hydraulic_conductivity      3.669226      4.161348
# soil__texture                               3.000000      4.000000
# soil__thickness                            44.000000    116.000000
# soil__transmissivity                        1.622539      4.081370
# topographic__elevation                    378.187454    778.035873
# vegetation__plant_functional_type           1.000000      3.000000
# wilting__point                              0.096446      0.132649
#
#                                                  max  missing_frac
# burn__severity                              0.000000           0.0
# cation__exchange_capacity                 329.000000           0.0
# clay__total                                26.000000           0.0
# dem_diff                                   26.533630           0.0
# dry__bulk_density                         166.000000           0.0
# field__capacity                             0.314610           0.0
# landcover                                  90.000000           0.0
# pH                                        727.000000           0.0
# porosity                                    0.451000           0.0
# sand__total                                67.000000           0.0
# saturated__water_content                    0.407372           0.0
# silt__total                                33.000000           0.0
# soil__density                            3023.679443           0.0
# soil__internal_friction_angle              34.000000           0.0
# soil__maximum_total_cohesion            20000.000000           0.0
# soil__minimum_total_cohesion             4000.000000           0.0
# soil__mode_total_cohesion               10000.000000           0.0
# soil__saturated_hydraulic_conductivity      9.343681           0.0
# soil__texture                               7.000000           0.0
# soil__thickness                           201.000000           0.0
# soil__transmissivity                       18.780798           0.0
# topographic__elevation                   1177.950073           0.0
# vegetation__plant_functional_type           3.000000           0.0
# wilting__point                              0.155702           0.0

# %%
pearson = df.corr(method="pearson", numeric_only=True)
spearman = df.corr(method="spearman", numeric_only=True)

target_corr = pd.DataFrame({
    "pearson_to_dem_diff": pearson["dem_diff"].drop("dem_diff"),
    "spearman_to_dem_diff": spearman["dem_diff"].drop("dem_diff"),
}).sort_values("pearson_to_dem_diff", key=lambda s: s.abs(), ascending=False)

display(target_corr)
# Out:
#                                         pearson_to_dem_diff  \
# soil__thickness                                    0.078884
# vegetation__plant_functional_type                  0.074585
# soil__transmissivity                               0.067865
# pH                                                 0.067415
# soil__internal_friction_angle                      0.067146
# landcover                                         -0.062547
# topographic__elevation                            -0.061147
# sand__total                                       -0.047590
# silt__total                                        0.045880
# field__capacity                                    0.041700
# wilting__point                                     0.041011
# soil__maximum_total_cohesion                      -0.040946
# soil__minimum_total_cohesion                      -0.040631
# clay__total                                        0.039738
# porosity                                           0.037009
# soil__texture                                      0.034027
# soil__saturated_hydraulic_conductivity             0.030437
# soil__mode_total_cohesion                         -0.029807
# soil__density                                      0.024256
# cation__exchange_capacity                          0.019894
# saturated__water_content                           0.015918
# dry__bulk_density                                 -0.006317
# burn__severity                                          NaN
#
#                                         spearman_to_dem_diff
# soil__thickness                                     0.175571
# vegetation__plant_functional_type                   0.187700
# soil__transmissivity                                0.198094
# pH                                                  0.158552
# soil__internal_friction_angle                       0.115994
# landcover                                          -0.186894
# topographic__elevation                             -0.024249
# sand__total                                        -0.078170
# silt__total                                         0.059210
# field__capacity                                     0.060018
# wilting__point                                      0.059385
# soil__maximum_total_cohesion                       -0.030908
# soil__minimum_total_cohesion                       -0.030908
# clay__total                                         0.100244
# porosity                                            0.055623
# soil__texture                                       0.059385
# soil__saturated_hydraulic_conductivity              0.161018
# soil__mode_total_cohesion                          -0.030908
# soil__density                                       0.084633
# cation__exchange_capacity                          -0.088280
# saturated__water_content                           -0.037662
# dry__bulk_density                                   0.068693
# burn__severity                                           NaN

# %%
pearson = df.corr(method="pearson", numeric_only=True)
spearman = df.corr(method="spearman", numeric_only=True)

target_corr = pd.DataFrame({
    "pearson_to_dem_diff": pearson["dem_diff"].drop("dem_diff"),
    "spearman_to_dem_diff": spearman["dem_diff"].drop("dem_diff"),
}).sort_values("pearson_to_dem_diff", key=lambda s: s.abs(), ascending=False)

ax = target_corr.plot(
    kind="bar",
    figsize=(14, 6),
    width=0.8,
)

ax.set_title("Feature Correlation with dem_diff")
ax.set_ylabel("Correlation")
ax.set_xlabel("Feature")
ax.axhline(0, color="black", linewidth=1)
plt.xticks(rotation=75, ha="right")
plt.tight_layout()
plt.show()

# %%
def plot_corr_matrix(corr_df, title, figsize=(12, 10)):
    fig, ax = plt.subplots(figsize=figsize)
    im = ax.imshow(corr_df.values, vmin=-1, vmax=1, cmap="coolwarm")
    ax.set_xticks(range(len(corr_df.columns)))
    ax.set_xticklabels(corr_df.columns, rotation=90, fontsize=8)
    ax.set_yticks(range(len(corr_df.index)))
    ax.set_yticklabels(corr_df.index, fontsize=8)
    ax.set_title(title)
    fig.colorbar(im, ax=ax, shrink=0.8)
    plt.tight_layout()
    plt.show()

plot_corr_matrix(pearson, "Pearson Correlation Matrix")
plot_corr_matrix(spearman, "Spearman Correlation Matrix")

# %%
import math
import matplotlib.pyplot as plt

cols = list(df.columns)  # assumes df already exists and includes dem_diff
n = len(cols)
ncols = 4
nrows = math.ceil(n / ncols)

fig, axes = plt.subplots(nrows, ncols, figsize=(4*ncols, 3*nrows))
axes = axes.flatten()

for ax, col in zip(axes, cols):
    ax.hist(df[col].dropna(), bins=50)
    ax.set_title(col, fontsize=9)

for ax in axes[n:]:
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

features = [c for c in df.columns if c != "dem_diff"]
n = len(features)
ncols = 4
nrows = math.ceil(n / ncols)

fig, axes = plt.subplots(nrows, ncols, figsize=(5*ncols, 4*nrows))
axes = axes.flatten()

for ax, feature in zip(axes, features):
    x = df[feature].to_numpy(dtype=float)
    y = df["dem_diff"].to_numpy(dtype=float)

    mask = np.isfinite(x) & np.isfinite(y)
    x = x[mask]
    y = y[mask]

    if len(x) < 2:
        ax.set_title(f"{feature}\nNot enough data", fontsize=10)
        ax.axis("off")
        continue

    r = np.corrcoef(x, y)[0, 1] if np.std(x) > 0 and np.std(y) > 0 else np.nan

    ax.scatter(x, y, s=8, alpha=0.4)

    ax.text(
        0.05, 0.95,
        f"r = {r:.2f}" if np.isfinite(r) else "r = NA",
        transform=ax.transAxes,
        ha="left",
        va="top",
        fontsize=10,
        bbox=dict(facecolor="white", alpha=0.7, edgecolor="none"),
    )

    ax.set_title(feature, fontsize=10)
    ax.set_xlabel(feature)
    ax.set_ylabel("dem_diff")

for ax in axes[n:]:
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
# If needed once:
# !pip install openpyxl

from pathlib import Path
import pandas as pd

downloads = Path("/mnt/c/Users/amehedi/Downloads")

def extract_hourly_window(event_name, start_date, end_date, agg="mean"):
    csv_path = downloads / f"{event_name}.csv"
    out_path = downloads / f"{event_name}.xlsx"

    df = pd.read_csv(csv_path)
    print("Columns:", df.columns.tolist())

    # Parse and clean
    df["time"] = pd.to_datetime(df["time"], utc=True, errors="coerce")
    df["value"] = pd.to_numeric(df["value"], errors="coerce")
    df = df.dropna(subset=["time", "value"]).sort_values("time")

    # Full-date window: start_date 00:00 through end_date 23:59:59
    start_dt = pd.to_datetime(start_date, utc=True)
    end_dt_exclusive = pd.to_datetime(end_date, utc=True) + pd.Timedelta(days=1)

    window_df = df.loc[
        (df["time"] >= start_dt) & (df["time"] < end_dt_exclusive),
        ["time", "value"]
    ].copy()

    if window_df.empty:
        print("No data found in that time window.")
        return window_df

    # Convert to hourly
    hourly = (
        window_df.set_index("time")["value"]
        .resample("1H")
        .agg(agg)
        .dropna()
        .reset_index()
        .rename(columns={"time": "timestamp", "value": "discharge"})
    )

    # Excel cannot store timezone-aware datetimes, so keep them as UTC-naive
    hourly["timestamp"] = hourly["timestamp"].dt.tz_convert("UTC").dt.tz_localize(None)

    hourly.to_excel(out_path, index=False)
    print(f"Saved: {out_path}")

    return hourly

# Example
out_df = extract_hourly_window(
    event_name="isaias",
    start_date="2020-08-03",
    end_date="2020-08-05",
    agg="mean",   # change to "max" or "sum" if needed
)

display(out_df.head())
display(out_df.tail())
# Out:
# Requirement already satisfied: openpyxl in /home/abdullah/miniconda3/envs/ml_debris/lib/python3.10/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /home/abdullah/miniconda3/envs/ml_debris/lib/python3.10/site-packages (from openpyxl) (2.0.0)
# WARNING: Error parsing dependencies of certifi: [Errno 2] No such file or directory: '/home/abdullah/miniconda3/envs/ml_debris/lib/python3.10/site-packages/certifi-2025.11.12.dist-info/METADATA'
# Columns: ['id', 'time_series_id', 'monitoring_location_id', 'parameter_code', 'statistic_id', 'time', 'value', 'unit_of_measure', 'approval_status', 'qualifier', 'last_modified']
# Saved: /mnt/c/Users/amehedi/Downloads/isaias.xlsx
# /tmp/ipykernel_1670/3602226691.py:37: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   .resample("1H")
#             timestamp  discharge
# 0 2020-08-03 04:00:00  28.933333
# 1 2020-08-03 05:00:00  29.266667
# 2 2020-08-03 06:00:00  30.000000
# 3 2020-08-03 07:00:00  30.600000
# 4 2020-08-03 08:00:00  31.125000
#              timestamp  discharge
# 63 2020-08-05 19:00:00     67.250
# 64 2020-08-05 20:00:00     66.625
# 65 2020-08-05 21:00:00     66.500
# 66 2020-08-05 22:00:00     66.375
# 67 2020-08-05 23:00:00     66.375
